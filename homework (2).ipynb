# %% [markdown]
# ###fetch_california_housing는 Scikit-Learn 라이브러리에서 제공하는 데이터셋 로더 함수 중 하나로, 캘리포니아 주택 가격 데이터입니다

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import fetch_california_housing # Import the fetch_california_housing function
housing = fetch_california_housing(as_frame=True) # Use the fetch_california_housing function to load the dataset

print(housing.keys())

# housing.values()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
housing.values()
# Out:
# dict_values([       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# ...

# %%
housing['target']
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
data = pd.DataFrame(housing['data'], columns = housing['feature_names'])
target = pd.DataFrame(housing['target'])

print(data.shape)
print(target.shape)
# Out:
# (20640, 8)
# (20640, 1)

# %%
data
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
target.columns = ['target']
target
# Out:
#        target
# 0       4.526
# 1       3.585
# 2       3.521
# 3       3.413
# 4       3.422
# ...       ...
# 20635   0.781
# 20636   0.771
# 20637   0.923
# 20638   0.847
# 20639   0.894
#
# [20640 rows x 1 columns]

# %%
df = pd.concat([data, target], axis=1)
df.head(5)
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %% [markdown]
#             MedInc (Median Income):
#             설명: 블록 그룹의 중간 소득.
#             단위: (단위는 천 달러로 표시됩니다).
#
#             HouseAge:
#             설명: 블록 그룹의 주택 연수.
#             단위: (단위는 년).
#
#             AveRooms (Average Rooms):
#             설명: 주택당 평균 방 개수.
#             단위: (특정 단위는 없고, 방 개수의 평균값을 나타냅니다).
#
#             AveBedrms (Average Bedrooms):
#             설명: 주택당 평균 침실 개수.
#             단위: (특정 단위는 없고, 침실 개수의 평균값을 나타냅니다).
#
#             Population:
#             설명: 블록 그룹의 인구수.
#             단위: (사람 수).
#
#             AveOccup (Average Occupants):
#             설명: 가구당 평균 거주자 수.
#             단위: (사람 수의 평균값을 나타냅니다).
#
#             Latitude:
#             설명: 블록 그룹의 위도.
#             단위: (도 단위).
#
#             Longitude:
#             설명: 블록 그룹의 경도.
#             단위: (도 단위).
#
#             target (Median House Value):
#             설명: 블록 그룹의 중간 주택 가격.
#             단위: (단위는 천 달러로 표시됩니다).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   target      20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# target        0
# dtype: int64

# %%
df_corr = df.corr()
df_corr
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# target      0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude    target
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
plt.figure(figsize=(10,10))
sns.set(font_scale = 0.8)
sns.heatmap(df_corr, annot = True, cbar=True, square = True)
plt.show()

# %%
corr_order = df.corr().loc[:'Longitude', 'target'].abs().sort_values(ascending=False)
corr_order
# Out:
# MedInc        0.688075
# AveRooms      0.151948
# Latitude      0.144160
# HouseAge      0.105623
# AveBedrms     0.046701
# Longitude     0.045967
# Population    0.024650
# AveOccup      0.023737
# Name: target, dtype: float64

# %%
plot_cols = ['target','MedInc','AveRooms','Latitude','HouseAge']
plot_df = df.loc[: , plot_cols]
plot_df.head()
# Out:
#    target  MedInc  AveRooms  Latitude  HouseAge
# 0   4.526  8.3252  6.984127     37.88      41.0
# 1   3.585  8.3014  6.238137     37.86      21.0
# 2   3.521  7.2574  8.288136     37.85      52.0
# 3   3.413  5.6431  5.817352     37.85      52.0
# 4   3.422  3.8462  6.281853     37.85      52.0

# %%
plt.figure(figsize=(10,10))
for idx, col in enumerate(plot_cols[1:]):
    axl = plt.subplot(2,2, idx +1)
    sns.regplot(x=col, y=plot_cols[0], data =plot_df, ax=axl)
plt.show()

# %%
sns.displot(x='target', kind= 'hist', data =df)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_scaled = df.iloc[:, :-1]
df_scaled
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
scaler.fit(df_scaled)   ## scaler를 학습시키는 과정,각 특성(feature)의 최소값과 최대값을 계산
df_scaled
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df_scaled = scaler.transform(df_scaled)  ##학습된 스케일러를 사용하여 데이터를 0과 1 사이의 값으로 변환
df_scaled
# Out:
# array([[0.53966842, 0.78431373, 0.0435123 , ..., 0.00149943, 0.5674814 ,
#         0.21115538],
#        [0.53802706, 0.39215686, 0.03822395, ..., 0.00114074, 0.565356  ,
#         0.21215139],
#        [0.46602805, 1.        , 0.05275646, ..., 0.00169796, 0.5642933 ,
#         0.21015936],
#        ...,
#        [0.08276438, 0.31372549, 0.03090386, ..., 0.0013144 , 0.73219979,
#         0.31175299],
#        [0.09429525, 0.33333333, 0.03178269, ..., 0.0011515 , 0.73219979,
#         0.30179283],
#        [0.13025338, 0.29411765, 0.03125246, ..., 0.00154886, 0.72582359,
#         0.30976096]])

# %%
df.iloc[:,:-1] = df_scaled[:,:] ## 재할당
df.head()
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  0.539668  0.784314  0.043512   0.020469    0.008941  0.001499  0.567481
# 1  0.538027  0.392157  0.038224   0.018929    0.067210  0.001141  0.565356
# 2  0.466028  1.000000  0.052756   0.021940    0.013818  0.001698  0.564293
# 3  0.354699  1.000000  0.035241   0.021929    0.015555  0.001493  0.564293
# 4  0.230776  1.000000  0.038534   0.022166    0.015752  0.001198  0.564293
#
#    Longitude  target
# 0   0.211155   4.526
# 1   0.212151   3.585
# 2   0.210159   3.521
# 3   0.209163   3.413
# 4   0.209163   3.422

# %%
from sklearn.model_selection import train_test_split
x_data = df.loc[:,['MedInc','AveRooms']]
y_data = df.loc[:,'target']
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, shuffle =True, random_state = 12)

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (16512, 2) (16512,)
# (4128, 2) (4128,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)

print('회귀계수(기울기):', np.round(lr.coef_,1))
print('상수항(절편):', np.round(lr.intercept_,1))
# Out:
# 회귀계수(기울기): [ 6.3 -4.8]
# 상수항(절편): 0.8

# %%
y_test_pred = lr.predict(x_test)

plt.figure(figsize=(10,5))
plt.scatter(x_test['MedInc'], y_test, label = 'y_test')
plt.scatter(x_test['MedInc'], y_test_pred, label = 'y_pred')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
y_train_pred = lr.predict(x_train)

train_mse = mean_squared_error(y_train, y_train_pred)
print('Train MSE: %.4f'% train_mse)

test_mse =mean_squared_error(y_test, y_test_pred)
print("Test MSE:%.4f"% test_mse)
# Out:
# Train MSE: 0.6937
# Test MSE:0.6916

# %%
from sklearn.model_selection import cross_val_score
lr = LinearRegression()
mse_scores = -1*cross_val_score(lr, x_train, y_train, cv=5, scoring = 'neg_mean_squared_error')

print('개별 Fold의 MSE:', np.round(mse_scores, 4))
print('평균 MSE:%.4f'% np.mean(mse_scores))
# Out:
# 개별 Fold의 MSE: [0.7001 0.6701 0.7237 0.6549 0.7308]
# 평균 MSE:0.6959

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
import numpy as np

# 모델 생성
lr = LinearRegression()

# 교차 검증 수행 (5-폴드 교차 검증, R² 사용)
r2_scores = cross_val_score(lr, x_train, y_train, cv=5, scoring='r2')

# 개별 폴드의 R² 출력
print('개별 Fold의 R²:', np.round(r2_scores, 4))

# 평균 R² 출력
print('평균 R²: %.4f' % np.mean(r2_scores))
# Out:
# 개별 Fold의 R²: [0.4682 0.4799 0.474  0.5032 0.4409]
# 평균 R²: 0.4732

# %%
import statsmodels.api as sm

# statsmodels를 사용한 회귀 분석
x_train_sm = sm.add_constant(x_train)  # 상수항 추가
model = sm.OLS(y_train, x_train_sm).fit()

# 결과 요약 출력
print(model.summary())

# 다중 상관계수
r_squared = model.rsquared
print(f'다중 상관계수 (R^2): {r_squared:.4f}')

# 표준오차, t통계량, p값, 신뢰구간
coefficients = model.params
std_errors = model.bse
t_values = model.tvalues
p_values = model.pvalues
conf_intervals = model.conf_int()

print("\n계수:")
print(coefficients)
print("\n표준오차:")
print(std_errors)
print("\nT-통계량:")
print(t_values)
print("\nP-값:")
print(p_values)
print("\n95% 신뢰구간:")
print(conf_intervals)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 target   R-squared:                       0.475
# Model:                            OLS   Adj. R-squared:                  0.475
# Method:                 Least Squares   F-statistic:                     7468.
# Date:                Sun, 02 Jun 2024   Prob (F-statistic):               0.00
# Time:                        05:42:05   Log-Likelihood:                -20410.
# No. Observations:               16512   AIC:                         4.083e+04
# Df Residuals:                   16509   BIC:                         4.085e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.7600      0.016     48.580      0.000       0.729       0.791
# ...
